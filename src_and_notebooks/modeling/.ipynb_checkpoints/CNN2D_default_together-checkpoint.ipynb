# %%
# %run ../processing/read_data.py
# %run ../processing/functions.ipynb

import numpy as np
import pandas as pd
import os
from PIL import Image

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn import model_selection

# %%
from __future__ import absolute_import, division, print_function
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Conv3D, MaxPooling3D, ZeroPadding3D
# Helper libraries
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.13.1

# %%
path_to_read = '../../data/dl_marcelo_no_treat/'
files = []

for r, d, f in os.walk(path_to_read):
    for file in f:
        if '.png' in file:
            files.append(os.path.join(r, file))
files.sort()
np_files = np.asarray(files)

# %%
len(np_files)
# Out:
# 85264

# %%
conversion = {'IIL_' : 5, 'IIP_' : 7, '_II_' : 4, 'IIn_' : 6, '_Ia_' : 0, '_Ib_' : 1, 'Ibc_' : 2, '_Ic_' : 3}
conversion_bool = {'IIL_' : 0, 'IIP_' : 0, '_II_' : 0, 'IIn_' : 0, '_Ia_' : 1, '_Ib_' : 0, 'Ibc_' : 0, '_Ic_' : 0}

# %%
c = [0,0,0,0]
idx = []
i = 0
while i < len(np_files):
    if 'desg' in np_files[i]:
        c[0] = 1
    if 'desi' in np_files[i+1]:
        c[1] = 1
    if 'desr' in np_files[i+2]:
        c[2] = 1
    if 'desz' in np_files[i+3]:
        c[3] = 1
    if c == [1,1,1,1]:
        i = i + 4
        c = [0,0,0,0]
    elif c[1] == 0:
        idx.append(i)
        i = i+1
    elif c[2] == 0:
        idx.append(i)
        idx.append(i+1)
        i = i+2
    elif c[3] == 0:
        idx.append(i)
        idx.append(i+1)  
        idx.append(i+2)
        i = i+3

# %%
np_files = np.delete(np_files, idx)
len(np_files)
# Out:
# 85264

# %%
np_grouped = np_files.reshape(round(np_files.shape[0]/4), 4)
class_id = []
#CHANGE HERE THE INDEX EVERYTIME WE CHANGE THE NAME FROM THE PATH OF THE FOLDER
for g in np_grouped:
    class_id = class_id + [[g[0][-20:-12], g[0][-12:-8]]] 
types = []
types_bool = []
for ids in class_id:
    types = types + [conversion[ids[1]]]
    types_bool = types_bool + [conversion_bool[ids[1]]]
    
astr_objs = []
for i in range(len(np_grouped)):
    astr_objs = astr_objs + [class_id[i]]
    for file in np_grouped[i]:
        img = Image.open(file).convert('L')
        arr = np.array(img)
        astr_objs[-1] = astr_objs[-1] + [arr[5:35,10:56]] 
        #CHANGE HERE IF WE EVENTUALLY CHANGE THE SIZE OF THE IMAGE, OR WANT TO CUT OTHER FRAMES

print( "The quantity of objects is: ", len(astr_objs))
# Out:
# The quantity of objects is:  21316

# %% [markdown]
# # K-FOLD

# %%
labels = []
images = []
ids = []
for o in astr_objs:
    labels.append((conversion_bool[o[1]])) #converting here to numbers to assure label in training
    desg = o[2]
    desi = o[3]
    desr = o[4]
    desz = o[5]
    gather = np.concatenate((desg,desi,desr,desz),axis = 1)
    images.append(gather)
    ids.append(o[0])
labels = np.asarray(labels)
images = np.asarray(images)
ids = np.asarray(ids)

Xb = images
yb = labels
kfb = KFold(n_splits=5)
Xb_train = []
Xb_test = []
yb_train = []
yb_test = []
id_train = []
id_test = []
for train_index, test_index in kfb.split(Xb):
    print("TRAIN:", train_index, "TEST:", test_index)
    Xb_train.append(Xb[train_index])
    Xb_test.append(Xb[test_index])
    yb_train.append(yb[train_index])
    yb_test.append(yb[test_index])
    id_train.append(ids[train_index])
    id_test.append(ids[test_index])
# Out:
# TRAIN: [ 4264  4265  4266 ... 21313 21314 21315] TEST: [   0    1    2 ... 4261 4262 4263]
# TRAIN: [    0     1     2 ... 21313 21314 21315] TEST: [4264 4265 4266 ... 8524 8525 8526]
# TRAIN: [    0     1     2 ... 21313 21314 21315] TEST: [ 8527  8528  8529 ... 12787 12788 12789]
# TRAIN: [    0     1     2 ... 21313 21314 21315] TEST: [12790 12791 12792 ... 17050 17051 17052]
# TRAIN: [    0     1     2 ... 17050 17051 17052] TEST: [17053 17054 17055 ... 21313 21314 21315]

# %%
print('The shapes of the objects are:')
print('ids: ', ids.shape)
print('labels: ', labels.shape)
print('images: ', images.shape)
print('train_images: ', Xb_train[0].shape)
print('Other useful object: "test_images"')
# Out:
# The shapes of the objects are:
# ids:  (21316,)
# labels:  (21316,)
# images:  (21316, 30, 184)
# train_images:  (17052, 30, 184)
# Other useful object: "test_images"

# %%
#import pickle
#
#r = [Xb_train,Xb_test]
#pickle_out = open("../../models/Xbs_default_together.pickle","wb")
#pickle.dump(r, pickle_out)
#pickle_out.close()
#

# %%
#This cell bugs the pc a little
#Normalization and separating the folds to the models
#train_images = np.around(Xb_train[0]/255, decimals = 2)
#test_images = np.around(Xb_test[0]/255, decimals = 2)
#x_train = train_images.reshape(train_images.shape[0], img_rows, img_cols, 1)
#
#
#train_images1 = np.around(Xb_train[1]/255, decimals = 2)
#test_images1 = np.around(Xb_test[1]/255, decimals = 2)
#x_train1 = train_images1.reshape(train_images1.shape[0], img_rows, img_cols, 1)
#
#
#train_images2 = np.around(Xb_train[2]/255, decimals = 2)
#test_images2 = np.around(Xb_test[2]/255, decimals = 2)
#x_train2 = train_images2.reshape(train_images2.shape[0], img_rows, img_cols, 1)
#
#
#train_images3 = np.around(Xb_train[3]/255, decimals = 2)
#test_images3 = np.around(Xb_test[3]/255, decimals = 2)
#x_train3 = train_images3.reshape(train_images3.shape[0], img_rows, img_cols, 1)
#
#
#train_images4 = np.around(Xb_train[4]/255, decimals = 2)
#test_images4 = np.around(Xb_test[4]/255, decimals = 2)
#x_train4 = train_images4.reshape(train_images4.shape[0], img_rows, img_cols, 1)

# %%
import pickle

pickle_results = open("../../models/x_train0_and_test_images.pickle","rb")
r = pickle.load(pickle_results)

x_train = r[0]
test_images= r[1]

# %%
pickle_results = open("../../models/x_train4_and_test_images.pickle","rb")
r = pickle.load(pickle_results)

x_train4 = r[0]
test_images4= r[1]

# %% [markdown]
# # Model Convolution NN 2D

# %%
np.random.seed(9)
img_rows, img_cols = 30, 184
input_shape = (img_rows,img_cols,1)

model_cv = Sequential()

model_cv.add(Conv2D(64, kernel_size=(4,4), padding='same', activation='relu', input_shape=input_shape))
model_cv.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=input_shape))
model_cv.add(MaxPooling2D(pool_size=(2,2)))
model_cv.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=input_shape))
model_cv.add(MaxPooling2D(pool_size=(2,2)))


model_cv.add(Flatten())
model_cv.add(Dense(2, activation=tf.nn.softmax))

model_cv.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 184, 64)       1088
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 30, 184, 64)       36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 92, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 92, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 46, 64)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 20608)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 41218
# =================================================================
# Total params: 116,162
# Trainable params: 116,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.random.seed(9)
model_cv.compile(optimizer='adam', #optimizer = 'adadelta'
              loss='sparse_categorical_crossentropy', #loss = "binary_crossentropy"
              metrics=['accuracy'])

# %%
np.random.seed(9)
model_cv.fit(x_train, yb_train[0], #validation_split = 0.1
             epochs=10)
# Out:
# Epoch 1/10
# 17052/17052 [==============================] - 341s 20ms/sample - loss: 0.3933 - acc: 0.8118
# Epoch 2/10
# 17052/17052 [==============================] - 336s 20ms/sample - loss: 0.3136 - acc: 0.8471
# Epoch 3/10
# 17052/17052 [==============================] - 334s 20ms/sample - loss: 0.2982 - acc: 0.8571
# Epoch 4/10
# 17052/17052 [==============================] - 333s 20ms/sample - loss: 0.2854 - acc: 0.8645
# Epoch 5/10
# 17052/17052 [==============================] - 333s 20ms/sample - loss: 0.2713 - acc: 0.8726
# Epoch 6/10
# 17052/17052 [==============================] - 329s 19ms/sample - loss: 0.2607 - acc: 0.8827
# Epoch 7/10
# 17052/17052 [==============================] - 330s 19ms/sample - loss: 0.2493 - acc: 0.8855
# Epoch 8/10
# 17052/17052 [==============================] - 329s 19ms/sample - loss: 0.2380 - acc: 0.8946
# Epoch 9/10
# 17052/17052 [==============================] - 329s 19ms/sample - loss: 0.2283 - acc: 0.8995
# Epoch 10/10
# 17052/17052 [==============================] - 328s 19ms/sample - loss: 0.2149 - acc: 0.9055

# %% [markdown]
# ### With Kfold 4

# %%
np.random.seed(9)
img_rows, img_cols = 30, 184
input_shape = (img_rows,img_cols,1)

model_cv4 = Sequential()

model_cv4.add(Conv2D(64, kernel_size=(4,4), padding='same', activation='relu', input_shape=input_shape))
model_cv4.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=input_shape))
model_cv4.add(MaxPooling2D(pool_size=(2,2)))
model_cv4.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=input_shape))
model_cv4.add(MaxPooling2D(pool_size=(2,2)))


model_cv4.add(Flatten())
model_cv4.add(Dense(2, activation=tf.nn.softmax))

model_cv4.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 30, 184, 64)       1088
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 30, 184, 64)       36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 92, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 15, 92, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 46, 64)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 20608)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 41218
# =================================================================
# Total params: 116,162
# Trainable params: 116,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.random.seed(9)
model_cv4.compile(optimizer='adam', #optimizer = 'adadelta'
              loss='sparse_categorical_crossentropy', #loss = "binary_crossentropy"
              metrics=['accuracy'])

# %%
np.random.seed(9)
model_cv4.fit(x_train4, yb_train[4], #validation_split = 0.1
             epochs=10)
# Out:
# Epoch 1/10
# 17053/17053 [==============================] - 331s 19ms/sample - loss: 0.4028 - acc: 0.8090
# Epoch 2/10
# 17053/17053 [==============================] - 330s 19ms/sample - loss: 0.3192 - acc: 0.8451
# Epoch 3/10
# 17053/17053 [==============================] - 330s 19ms/sample - loss: 0.2985 - acc: 0.8580
# Epoch 4/10
# 17053/17053 [==============================] - 328s 19ms/sample - loss: 0.2808 - acc: 0.8684
# Epoch 5/10
# 17053/17053 [==============================] - 328s 19ms/sample - loss: 0.2672 - acc: 0.8759
# Epoch 6/10
# 17053/17053 [==============================] - 327s 19ms/sample - loss: 0.2544 - acc: 0.8844
# Epoch 7/10
# 17053/17053 [==============================] - 327s 19ms/sample - loss: 0.2444 - acc: 0.8918
# Epoch 8/10
# 17053/17053 [==============================] - 328s 19ms/sample - loss: 0.2330 - acc: 0.8986
# Epoch 9/10
# 17053/17053 [==============================] - 327s 19ms/sample - loss: 0.2219 - acc: 0.9009
# Epoch 10/10
# 17053/17053 [==============================] - 327s 19ms/sample - loss: 0.2112 - acc: 0.9085

# %% [markdown]
# # Evaluation

# %%
x_test = test_images.reshape(test_images.shape[0], img_rows, img_cols, 1)
test_loss_cv, test_acc_cv = model_cv.evaluate(x_test, yb_test[0])

print('Test accuracy model_cv:', test_acc_cv)
print('Test loss model_cv:', test_loss_cv)
# Out:
# 4264/4264 [==============================] - 25s 6ms/sample - loss: 0.3139 - acc: 0.8569
# Test accuracy model_cv: 0.8569418
# Test loss model_cv: 0.31386485405084563

# %%
x_test4 = test_images4.reshape(test_images4.shape[0], img_rows, img_cols, 1)
test_loss_cv4, test_acc_cv4 = model_cv4.evaluate(x_test4, yb_test[4])

print('Test accuracy model_cv:', test_acc_cv4)
print('Test loss model_cv:', test_loss_cv4)
# Out:
# 4263/4263 [==============================] - 25s 6ms/sample - loss: 0.3194 - acc: 0.8532
# Test accuracy model_cv: 0.8531551
# Test loss model_cv: 0.3193902236151913

# %% [markdown]
# # Confusion Matrices

# %%
fix_plot_bug()
pred = model_cv.predict(x_test)
pred_bool = transform(pred)
y_true = yb_test[0]
plot_confusion_matrix(y_true, pred_bool, ['Not IA', 'IA'],normalize=True )
plot_confusion_matrix(y_true, pred_bool, ['Not IA', 'IA'],normalize=False )
# Out:
# Normalized confusion matrix
# [[0.88568802 0.11431198]
#  [0.23676324 0.76323676]]
# <img src="data:image/png;base64,..." width="431.75000000000006">
# Confusion matrix, without normalization
# [[2890  373]
#  [ 237  764]]
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
pred = model_cv4.predict(x_test4)
pred_bool = transform(pred)
y_true = yb_test[4]
plot_confusion_matrix(y_true, pred_bool, ['Not IA', 'IA'],normalize=True )
plot_confusion_matrix(y_true, pred_bool, ['Not IA', 'IA'],normalize=False )
# Out:
# Normalized confusion matrix
# [[0.87967832 0.12032168]
#  [0.23009709 0.76990291]]
# <img src="data:image/png;base64,..." width="431.75000000000006">
# Confusion matrix, without normalization
# [[2844  389]
#  [ 237  793]]
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
3000+263+(311+690)
# Out:
# 4264

# %%
(2890+373)+(237+764)
# Out:
# 4264

# %% [markdown]
# ## invertendo

# %%
print(x_train.shape)
x_train_inv = x_train.reshape(17052,184,30,1)
print(x_train_inv.shape)

# %%
np.random.seed(9)
img_rows, img_cols = 30, 184
input_shape_inv = (img_cols,img_rows,1)

model_cv_inv = Sequential()

model_cv_inv.add(Conv2D(64, kernel_size=(4,4), padding='same', activation='relu', input_shape=input_shape_inv))
model_cv_inv.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=input_shape_inv))
model_cv_inv.add(MaxPooling2D(pool_size=(2,2)))
model_cv_inv.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=input_shape_inv))
model_cv_inv.add(MaxPooling2D(pool_size=(2,2)))


model_cv_inv.add(Flatten())
model_cv_inv.add(Dense(2, activation=tf.nn.softmax))

model_cv_inv.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 184, 30, 64)       1088
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 184, 30, 64)       36928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 92, 15, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 92, 15, 64)        36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 46, 7, 64)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 20608)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 41218
# =================================================================
# Total params: 116,162
# Trainable params: 116,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.random.seed(9)
model_cv_inv.compile(optimizer='adam', #optimizer = 'adadelta'
              loss='sparse_categorical_crossentropy', #loss = "binary_crossentropy"
              metrics=['accuracy'])

# %%
np.random.seed(9)
model_cv_inv.fit(x_train_inv, yb_train[0], #validation_split = 0.1
             epochs=10)
# Out:
# Epoch 1/10
# 17052/17052 [==============================] - 352s 21ms/sample - loss: 0.4693 - acc: 0.7835
# Epoch 2/10
# 17052/17052 [==============================] - 359s 21ms/sample - loss: 0.3334 - acc: 0.8390
# Epoch 3/10
# 17052/17052 [==============================] - 357s 21ms/sample - loss: 0.2982 - acc: 0.8605
# Epoch 4/10
# 17052/17052 [==============================] - 357s 21ms/sample - loss: 0.2813 - acc: 0.8697
# Epoch 5/10
# 17052/17052 [==============================] - 356s 21ms/sample - loss: 0.2633 - acc: 0.8785
# Epoch 6/10
# 17052/17052 [==============================] - 356s 21ms/sample - loss: 0.2490 - acc: 0.8879
# Epoch 7/10
# 17052/17052 [==============================] - 357s 21ms/sample - loss: 0.2382 - acc: 0.8946
# Epoch 8/10
# 17052/17052 [==============================] - 357s 21ms/sample - loss: 0.2276 - acc: 0.8998
# Epoch 9/10
# 17052/17052 [==============================] - 356s 21ms/sample - loss: 0.2123 - acc: 0.9062
# Epoch 10/10
# 17052/17052 [==============================] - 357s 21ms/sample - loss: 0.1990 - acc: 0.9123

# %%
x_test_inv = test_images.reshape(test_images.shape[0], img_cols, img_rows, 1)
test_loss_cv_inv, test_acc_cv_inv = model_cv_inv.evaluate(x_test_inv, yb_test[0])

print('Test accuracy model_cv:', test_acc_cv_inv)
print('Test loss model_cv:', test_loss_cv_inv)
# Out:
# 4264/4264 [==============================] - 26s 6ms/sample - loss: 0.3660 - acc: 0.8504
# Test accuracy model_cv: 0.85037524
# Test loss model_cv: 0.3660247048003141

# %%
fix_plot_bug()
pred = model_cv_inv.predict(x_test_inv)
pred_bool = transform(pred)
y_true = yb_test[0]
plot_confusion_matrix(y_true, pred_bool, ['Not IA', 'IA'],normalize=True )
plot_confusion_matrix(y_true, pred_bool, ['Not IA', 'IA'],normalize=False )
# Out:
# Normalized confusion matrix
# [[0.86270303 0.13729697]
#  [0.18981019 0.81018981]]
# <img src="data:image/png;base64,..." width="431.6333333333333">
# Confusion matrix, without normalization
# [[2815  448]
#  [ 190  811]]
# <img src="data:image/png;base64,..." width="431.6333333333333">
